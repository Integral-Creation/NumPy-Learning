# %% [markdown]
# # **NumPy**

# %% [markdown]
# #### `NumPy` (*Numerical Python*) is Python’s fundamental library for numerical computing.

# %%
import numpy as np

# %% [markdown]
# ### NumPy version

# %%
print(np.__version__)
# Out:
# 2.4.4

# %% [markdown]
# ## **Introduction to `NumPy` Array**

# %%
array = np.array([1,2,3,4,5])
print(array)
# Out:
# [1 2 3 4 5]

# %%
print(type(array))
# Out:
# <class 'numpy.ndarray'>

# %%
array = array * 2
print(array)
# Out:
# [ 2  4  6  8 10]
